# %% [markdown]
# # Get Tweets
#
# This code has been heavily modified and came from the following tutorial: https://github.com/alod83/data-science/tree/master/DataCollection/Twitter from user https://github.com/alod83
#
# This script extracts all the tweets with hashtag #HurricaneIan from the last four days and saves them into a .csv.gz file.
#
# Firstly, we import the configuration file, called `config.py`, which is located in the same directory of this script.

# %%
from config import *
import tweepy
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-abe92d8ef818> in <module>
# ----> 1 from config import *
#       2 import tweepy
#       3 import datetime
#
# ModuleNotFoundError: No module named 'config'

# %% [markdown]
# Then I'm going to set up my authorization and make an api object.

# %%
auth = tweepy.OAuth1UserHandler(api_key, api_secret, access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, retry_count=10, retry_delay=5, 
                 retry_errors=set([503]))

# %% [markdown]
# Now we setup dates. We need to setup today and the last four days.

# %%
today = datetime.date.today()
yesterday= today - datetime.timedelta(days=1)
last_four = today - datetime.timedelta(days = 4)
today, yesterday, last_four
# Out:
# (datetime.date(2022, 11, 13),
#  datetime.date(2022, 11, 12),
#  datetime.date(2022, 11, 9))

# %% [markdown]
# I'm going to make a list with all the returns of the tweepy.Cursor class and my arguments into that class will contain my query as "q", my day parameters, and make sure that I'm only grabbing tweets in their extended mode, and only ones in English.

# %%
tweets_list = tweepy.Cursor(api.search_tweets, q= "#HurricaneIan since:" + str(last_four)+ " until:" + str(today),
                            tweet_mode='extended', lang='en').items()

# %% [markdown]
# Now I loop across the `tweets_list`, and, for each tweet, we extract the text, the creation date, the number of retweets and the favourite count. I store every tweet into a list, called `output`.

# %%
backoff_counter = 1
    
while True:
    
    try:
        output = []
        for tweet in tweets_list:
            text = tweet._json["full_text"]
            screen_name = tweet._json['user']['screen_name']
            user_description = tweet._json['user']['description']
            favourite_count = tweet.favorite_count
            retweet_count = tweet.retweet_count
            created_at = tweet.created_at
            replying_to = tweet.in_reply_to_screen_name
            media = tweet.entities.get('media', [])
            hashtags = tweet.entities['hashtags']
            urls = tweet.entities['urls']
            user_mentions = tweet.entities['user_mentions']
            is_quote = tweet.is_quote_status

            is_media = False
            if media != []:
                is_media = True

            line = {'text' : text, 
                    'screen_name' : screen_name,
                    'user_description' : user_description,
                    'favourite_count' : favourite_count, 
                    'retweet_count' : retweet_count, 
                    'created_at' : created_at,
                   'replying_to' : replying_to,
                   'media' : is_media,
                   'hashtags' : hashtags,
                   'urls' : urls,
                   'user_mentions' : user_mentions,
                   'is_quote' : is_quote}
            output.append(line)
        break
        
        
    except tweepy.TweepyException as e:
        print(e)
        sleep(60*backoff_counter)
        backoff_counter += 1
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f1cd01791b32> in <module>
#       5     try:
#       6         output = []
# ----> 7         for tweet in tweets_list:
#       8             text = tweet._json["full_text"]
#       9             screen_name = tweet._json['user']['screen_name']
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/api.py in search_tweets(self, q, **kwargs)
#    1301         .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1302         """
# -> 1303         return self.request(
#    1304             'GET', 'search/tweets', endpoint_parameters=(
#    1305                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     214                 # Execute request
#     215                 try:
# --> 216                     resp = self.session.request(
#     217                         method, url, params=params, headers=headers,
#     218                         data=post_data, files=files, json=json_payload,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ERROR NOTES: As is, this code is currently not working without errors. The good news is that it's functional and can collect quite a lot of tweets and store them in 'output' if it either gets interrupted or I stop the program. 'output' can then be saved for later in a CSV format.

# %% [markdown]
# Finally, we convert the `output` list to a `pandas DataFrame` and we store results.

# %%
output
# Out:
# [{'text': 'Food Truck Park Madness in South West Florida https://t.co/DZBJp2JoBn\n.\n.\n.\n#keywest #keywestflorida #florida #hurricaneian #swflstrong #fmbstrong #sanibelstrong #floridakeys #conchrepublic #travel #travelflorida #staycation',
#   'screen_name': 'KeyWestExpress',
#   'user_description': '#KeyWestExpress Ferry sails from #FortMyersBeach year round and #MarcoIsland seasonally. The fastest and most fun way to visit #KeyWest!',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 53, 59, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'keywest', 'indices': [76, 84]},
#    {'text': 'keywestflorida', 'indices': [85, 100]},
#    {'text': 'florida', 'indices': [101, 109]},
#    {'text': 'hurricaneian', 'indices': [110, 123]},
#    {'text': 'swflstrong', 'indices': [124, 135]},
#    {'text': 'fmbstrong', 'indices': [136, 146]},
#    {'text': 'sanibelstrong', 'indices': [147, 161]},
#    {'text': 'floridakeys', 'indices': [162, 174]},
#    {'text': 'conchrepublic', 'indices': [175, 189]},
#    {'text': 'travel', 'indices': [190, 197]},
#    {'text': 'travelflorida', 'indices': [198, 212]},
#    {'text': 'staycation', 'indices': [213, 224]}],
#   'urls': [{'url': 'https://t.co/DZBJp2JoBn',
#     'expanded_url': 'https://bit.ly/3sMfYl5',
#     'display_url': 'bit.ly/3sMfYl5',
#     'indices': [46, 69]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: Ft Myers Beach is effectively gone, almost no emergency crews yet. These poor people need so much help… \n#HurricaneIan…',
#   'screen_name': 'Phugnut24Chevy',
#   'user_description': "South Jersey. Auto Tech. Gamer. Eagles Phillies Flyers fan. Cluster headache sufferer 10yrs. Fight for Democracy.\nHappily married 21 years. NO DM'S PLEASE.",
#   'favourite_count': 0,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 50, 41, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [126, 139]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: Ft Myers Beach is effectively gone, almost no emergency crews yet. These poor people need so much help… \n#HurricaneIan…',
#   'screen_name': 'kathybrinkcors2',
#   'user_description': 'My disgust for Trump and his cronies. Prison reform advocate. Hope for a future. My disgust for the impeached POS hasn’t ended. Da Bears. Go Cubs.',
#   'favourite_count': 0,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 46, 31, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [126, 139]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: Ft Myers Beach is effectively gone, almost no emergency crews yet. These poor people need so much help… \n#HurricaneIan…',
#   'screen_name': 'AprilGreen93',
#   'user_description': 'Not a damn thing makes me special',
#   'favourite_count': 0,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 44, 55, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [126, 139]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: Ft Myers Beach is effectively gone, almost no emergency crews yet. These poor people need so much help… \n#HurricaneIan…',
#   'screen_name': 'DennisCardiff',
#   'user_description': '🌊🌊#author(https://t.co/w2iEepGZ02)🌊(https://t.co/FbybYDAM3f) 💉💉💉💉🌊#blogger(https://t.co/19S8YjaIAp) 🌊🌊#poet(https://t.co/d1XYoaYT3W) 🇨🇦 #JailTrump #Resistance #BlueCrew #ProChoice',
#   'favourite_count': 0,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 44, 9, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [126, 139]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'Ft Myers Beach is effectively gone, almost no emergency crews yet. These poor people need so much help… \n#HurricaneIan\nhttps://t.co/gBooNMIHJF 02',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 7,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 30, 27, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [105, 118]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @kodiak149: .@Vanguard_Group @BarclaysCIB @the_rutabega \nAre you an owner of @HeritagePCI \nTerrible customer service\nWaiting 7 weeks sin…',
#   'screen_name': 'deniseharmon21',
#   'user_description': '',
#   'favourite_count': 0,
#   'retweet_count': 23,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 9, 6, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'kodiak149',
#     'name': 'kodiak149',
#     'id': 17444647,
#     'id_str': '17444647',
#     'indices': [3, 13]},
#    {'screen_name': 'Vanguard_Group',
#     'name': 'Vanguard',
#     'id': 61875147,
#     'id_str': '61875147',
#     'indices': [16, 31]},
#    {'screen_name': 'BarclaysCIB',
#     'name': 'Barclays Corporate & Investment Bank',
#     'id': 856524819948609536,
#     'id_str': '856524819948609536',
#     'indices': [32, 44]},
#    {'screen_name': 'the_rutabega',
#     'name': 'the rutabega',
#     'id': 900454999,
#     'id_str': '900454999',
#     'indices': [45, 58]},
#    {'screen_name': 'HeritagePCI',
#     'name': 'Heritage Insurance',
#     'id': 1136702616392675328,
#     'id_str': '1136702616392675328',
#     'indices': [80, 92]}],
#   'is_quote': False},
#  {'text': 'RT @MeganScavo: My boyfriend saving a cat from flood waters near Bonita Beach. #HurricaneIan #Naples #Bonita #FortMyers https://t.co/BlBC9P…',
#   'screen_name': 'TurgeonA2',
#   'user_description': '',
#   'favourite_count': 0,
#   'retweet_count': 20837,
#   'created_at': datetime.datetime(2022, 11, 12, 23, 5, 38, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [79, 92]},
#    {'text': 'Naples', 'indices': [93, 100]},
#    {'text': 'Bonita', 'indices': [101, 108]},
#    {'text': 'FortMyers', 'indices': [109, 119]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'MeganScavo',
#     'name': 'Megan Cruz Scavo',
#     'id': 880768820197163009,
#     'id_str': '880768820197163009',
#     'indices': [3, 14]}],
#   'is_quote': False},
#  {'text': 'RT @safiyyah3922: @RonDeSantisFL @CaseyDeSantis \nThank you!!! Thank you!!!\nNow RUN... Run.....Run.\nWe need you.\nPlease RUN and free the GOP…',
#   'screen_name': 'safiyyah3922',
#   'user_description': 'Gifted Educator and Blessed Success Faith Champion. Before all else, Almighty God. Through HIM I live and breathe. Psalm 31 : 15  My times are in THY hands...',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 22, 53, 13, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'safiyyah3922',
#     'name': 'DeeSuccessFaithChamp',
#     'id': 2412704687,
#     'id_str': '2412704687',
#     'indices': [3, 16]},
#    {'screen_name': 'RonDeSantisFL',
#     'name': 'Ron DeSantis',
#     'id': 487297085,
#     'id_str': '487297085',
#     'indices': [18, 32]},
#    {'screen_name': 'CaseyDeSantis',
#     'name': 'Casey DeSantis',
#     'id': 433365936,
#     'id_str': '433365936',
#     'indices': [33, 47]}],
#   'is_quote': False},
#  {'text': '@MelchiorDaniela Looking good 👍Any idea when you’re doing another convention or another signing with @swau_official? My #Ratcatcher2 poster was unfortunately lost during #HurricaneIan 😔 it was was of my most prized possessions but sadly got soaked and ruined #TheSuicideSquad #YouDontKnowSquad https://t.co/XiKgDZ1vBL',
#   'screen_name': 'HavenHuth',
#   'user_description': 'Writer of unpublished comics, podcaster, video editor, 4 Color Demon 🐜 2324, and co-host of #The616Show 📺 📧:havenhugefan@gmail.com',
#   'favourite_count': 5,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 22, 45, 37, tzinfo=datetime.timezone.utc),
#   'replying_to': 'MelchiorDaniela',
#   'media': True,
#   'hashtags': [{'text': 'Ratcatcher2', 'indices': [120, 132]},
#    {'text': 'HurricaneIan', 'indices': [170, 183]},
#    {'text': 'TheSuicideSquad', 'indices': [259, 275]},
#    {'text': 'YouDontKnowSquad', 'indices': [276, 293]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'MelchiorDaniela',
#     'name': 'Daniela Melchior',
#     'id': 711910943932948481,
#     'id_str': '711910943932948481',
#     'indices': [0, 16]},
#    {'screen_name': 'swau_official',
#     'name': 'SWAU',
#     'id': 1204700965695184896,
#     'id_str': '1204700965695184896',
#     'indices': [101, 115]}],
#   'is_quote': False},
#  {'text': 'RT @GRevmgbrown4: What??? #Black evacuees were "dumped" into a #Florida parking garage during #HurricaneIan??? That was utterly irresponsib…',
#   'screen_name': 'GRevmgbrown4',
#   'user_description': 'Pastor - Greater New Hope Baptist ChurchDC; Lecturer - #NationalBaptistCongressOfChristianEducation, NBC,USAInc. #ToGODBeTheGloryForTheGreatThingsThatHeHasDone',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 22, 27, 22, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Black', 'indices': [26, 32]},
#    {'text': 'Florida', 'indices': [63, 71]},
#    {'text': 'HurricaneIan', 'indices': [94, 107]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'GRevmgbrown4',
#     'name': 'Dr. Melvin G. Brown',
#     'id': 1161457548,
#     'id_str': '1161457548',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': 'What??? #Black evacuees were "dumped" into a #Florida parking garage during #HurricaneIan??? That was utterly irresponsible, entirely reprehensible, and absolutely \n#UNCONSCIONABLE!!!!!! 👇🏾👇🏾👇🏾👇🏾 🤔🤔🤔👎🏾👎🏾👎🏾👎🏾👎🏾👎🏾 https://t.co/UvWsLYA5E6',
#   'screen_name': 'GRevmgbrown4',
#   'user_description': 'Pastor - Greater New Hope Baptist ChurchDC; Lecturer - #NationalBaptistCongressOfChristianEducation, NBC,USAInc. #ToGODBeTheGloryForTheGreatThingsThatHeHasDone',
#   'favourite_count': 1,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 22, 26, 46, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'Black', 'indices': [8, 14]},
#    {'text': 'Florida', 'indices': [45, 53]},
#    {'text': 'HurricaneIan', 'indices': [76, 89]},
#    {'text': 'UNCONSCIONABLE', 'indices': [165, 180]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'The damage from #HurricaneIan is “catastrophic” and historic.\nhttps://t.co/OY323JCzyQ 04',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 22, 6, 24, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [16, 29]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': '#COP27 #Florida #HurricaneIan was a #Climate superstorm. https://t.co/cveO60AFFb',
#   'screen_name': 'CaHughes74',
#   'user_description': 'HFA. Organizer IA, NY, FL, UN Env Delegate, MSW, Const.Caseworker,Vic Advocate, FM DJ, E.Hampton, Bklyn, AmeriCorps,LIU library, MHP, NYS AG Env Award',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 59, 18, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'COP27', 'indices': [0, 6]},
#    {'text': 'Florida', 'indices': [7, 15]},
#    {'text': 'HurricaneIan', 'indices': [16, 29]},
#    {'text': 'Climate', 'indices': [36, 44]}],
#   'urls': [{'url': 'https://t.co/cveO60AFFb',
#     'expanded_url': 'https://twitter.com/CaHughes74/status/1591547722699796481',
#     'display_url': 'twitter.com/CaHughes74/sta…',
#     'indices': [57, 80]}],
#   'user_mentions': [],
#   'is_quote': True},
#  {'text': '9 Most Instagram Worthy Places in Key West https://t.co/w4zdBvRNC8.\n.\n.\n#keywest #keywestflorida #florida #hurricaneian #swflstrong #fmbstrong #sanibelstrong #floridakeys #conchrepublic #travel #travelflorida #staycation',
#   'screen_name': 'KeyWestExpress',
#   'user_description': '#KeyWestExpress Ferry sails from #FortMyersBeach year round and #MarcoIsland seasonally. The fastest and most fun way to visit #KeyWest!',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 53, 59, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'keywest', 'indices': [72, 80]},
#    {'text': 'keywestflorida', 'indices': [81, 96]},
#    {'text': 'florida', 'indices': [97, 105]},
#    {'text': 'hurricaneian', 'indices': [106, 119]},
#    {'text': 'swflstrong', 'indices': [120, 131]},
#    {'text': 'fmbstrong', 'indices': [132, 142]},
#    {'text': 'sanibelstrong', 'indices': [143, 157]},
#    {'text': 'floridakeys', 'indices': [158, 170]},
#    {'text': 'conchrepublic', 'indices': [171, 185]},
#    {'text': 'travel', 'indices': [186, 193]},
#    {'text': 'travelflorida', 'indices': [194, 208]},
#    {'text': 'staycation', 'indices': [209, 220]}],
#   'urls': [{'url': 'https://t.co/w4zdBvRNC8',
#     'expanded_url': 'https://bit.ly/3Ui6Oc2',
#     'display_url': 'bit.ly/3Ui6Oc2',
#     'indices': [43, 66]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @gaillevyontv: Bayfront Bistro on Fort Myers Beach is back open! They’re serving cold drinks, hot food, and WIFI! Check out how high the…',
#   'screen_name': 'ILoveMyCamaro',
#   'user_description': 'Loves cars, oak trees and traveling. Lobbyist for Physical Therapy as a patient of PT.',
#   'favourite_count': 0,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 52, 30, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'gaillevyontv',
#     'name': 'Gail Levy',
#     'id': 1004498563148275712,
#     'id_str': '1004498563148275712',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': 'Our hurricane debris finally got picked up!!! \n\nI almost ordered Christmas lights on Amazon to decorate the huge piles. \n\n#HurricaneIan https://t.co/WMby3ZrJeM',
#   'screen_name': 'ShredderBabe',
#   'user_description': "Drummer/Personal Trainer/Cheesecake Artist/Beer Girl ... here to kick ass & chew bubblegum & I'm all outta bubblegum. I don't believe in warning shots. DMs 🚫",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 47, 28, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [122, 135]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'The damage from #HurricaneIan is “catastrophic” and historic.\nhttps://t.co/OY323JCzyQ 03',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 45, 17, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [16, 29]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'Always apply! #FEMA funding is available regardless if you have received grant funding in previous disasters. #DisasterLaw #DisasterTips #HurricaneNicole #HurricaneIan #HurricaneFiona',
#   'screen_name': 'ELResponders',
#   'user_description': 'we help people faced with natural, social, & economic disasters solve legal challenges by providing free & accessible information and services.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 37, 13, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'FEMA', 'indices': [14, 19]},
#    {'text': 'DisasterLaw', 'indices': [110, 122]},
#    {'text': 'DisasterTips', 'indices': [123, 136]},
#    {'text': 'HurricaneNicole', 'indices': [137, 153]},
#    {'text': 'HurricaneIan', 'indices': [154, 167]},
#    {'text': 'HurricaneFiona', 'indices': [168, 183]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'While we\'re still watching how #TropicalStormNicole will subside, it seems like a good time for a post- #HurricaneIan look at the NFIP and the private flood insurance marketplace with Joe "Flood" Rossi. https://t.co/iRvTUqSXbn\n\n#CLMMagazine #Insurance #ClaimsManagement',
#   'screen_name': 'TheCLMalliance',
#   'user_description': 'The CLM Alliance promotes and furthers the highest standards of claims and litigation management and brings together thought leaders in both industries.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 35, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'TropicalStormNicole', 'indices': [31, 51]},
#    {'text': 'HurricaneIan', 'indices': [104, 117]},
#    {'text': 'CLMMagazine', 'indices': [228, 240]},
#    {'text': 'Insurance', 'indices': [241, 251]},
#    {'text': 'ClaimsManagement', 'indices': [252, 269]}],
#   'urls': [{'url': 'https://t.co/iRvTUqSXbn',
#     'expanded_url': 'http://bit.ly/3UpG35S',
#     'display_url': 'bit.ly/3UpG35S',
#     'indices': [203, 226]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'This Army Chinook is part of the FL National Guard and recently helped rescue people in Sanibel after #HurricaneIan. Also, note the fuzzy dice in the cockpit. 🎲 🚁 #StuartAirShow https://t.co/hC13QdxFig',
#   'screen_name': 'rumpfshaker',
#   'user_description': 'Coffee aficionado ☕️ @UF @UFLaw alumna 🐊 Contributing Editor @Mediaite & @lawcrimenews 📺 Freelance writer 💻 Aspiring pâtissière 🍰 *tweets = my opinion* 🇺🇸',
#   'favourite_count': 6,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 32, 46, tzinfo=datetime.timezone.utc),
#   'replying_to': 'rumpfshaker',
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [102, 115]},
#    {'text': 'StuartAirShow', 'indices': [163, 177]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @RedCrossCFL: U.S. Army #veterans Martha Narvaez &amp; Vincent Leandry joined the Red Cross together 2.5 years ago and recently volunteered…',
#   'screen_name': 'wendylooksleaps',
#   'user_description': 'Book reader. Travel writer. Card player. Red Cross team member. Always up for a good story. Views are my own.',
#   'favourite_count': 0,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 31, 31, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'veterans', 'indices': [27, 36]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'RedCrossCFL',
#     'name': 'American Red Cross of Central Florida & USVI',
#     'id': 15149447,
#     'id_str': '15149447',
#     'indices': [3, 15]}],
#   'is_quote': False},
#  {'text': '#FEMA Fact: If you are an #undocumented #immigrant &amp; you have a child under the age of 18 that lives with you, you may apply for #FEMA Individual and Households Program Assistance on their behalf. #HurricaneNicole #HurricaneIan #HurricaneFiona',
#   'screen_name': 'ELResponders',
#   'user_description': 'we help people faced with natural, social, & economic disasters solve legal challenges by providing free & accessible information and services.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 28, 10, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'FEMA', 'indices': [0, 5]},
#    {'text': 'undocumented', 'indices': [26, 39]},
#    {'text': 'immigrant', 'indices': [40, 50]},
#    {'text': 'FEMA', 'indices': [133, 138]},
#    {'text': 'HurricaneNicole', 'indices': [201, 217]},
#    {'text': 'HurricaneIan', 'indices': [218, 231]},
#    {'text': 'HurricaneFiona', 'indices': [232, 247]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'https://t.co/r3ebM7Hyat\n\nPlease click the link above ⬆️ To help us support the Families displaced 🙏⭐️💫✨🙌🦋\n\n#Hurricanes #Florida #fundraising #support #donation #love #supporteachother #HurricaneIan #Help #caring https://t.co/qLCYj0L0Nv',
#   'screen_name': 'deborahdriggs',
#   'user_description': 'Co-Author “Son of a Basque” 2022 ✍️ Blogger 📝 , DEBS DEN COACHING ✨ Where Healing Begins ✨',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 27, 6, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'Hurricanes', 'indices': [107, 118]},
#    {'text': 'Florida', 'indices': [119, 127]},
#    {'text': 'fundraising', 'indices': [128, 140]},
#    {'text': 'support', 'indices': [141, 149]},
#    {'text': 'donation', 'indices': [150, 159]},
#    {'text': 'love', 'indices': [160, 165]},
#    {'text': 'supporteachother', 'indices': [166, 183]},
#    {'text': 'HurricaneIan', 'indices': [184, 197]},
#    {'text': 'Help', 'indices': [198, 203]},
#    {'text': 'caring', 'indices': [204, 211]}],
#   'urls': [{'url': 'https://t.co/r3ebM7Hyat',
#     'expanded_url': 'http://www.hurricaneian.world/gofundme',
#     'display_url': 'hurricaneian.world/gofundme',
#     'indices': [0, 23]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'With two basically B2B hurricanes, our Florida beaches are covered in tons of trash… I challenge u and your friends to take a bag with u to the beach and fill it as much as u can! Anything helps\U0001faf6 #HurricaneIan #HurricaneNicole https://t.co/sdHq8cEOqr',
#   'screen_name': 'madisonm0121',
#   'user_description': 'UCF Rowing ‘26 ⚔️ https://t.co/906jWexecJ',
#   'favourite_count': 9,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 19, 41, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [196, 209]},
#    {'text': 'HurricaneNicole', 'indices': [210, 226]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: Naples. Houses are moving\n #HurricaneIan \nhttps://t.co/VRqckeBZkC 02',
#   'screen_name': 'xholonx',
#   'user_description': 'Aktuell: Ich entfolge Menschen die das retweeten gesperrt haben. J\nawohl Bio, insbesondere nur noch Bio-Bier, wg. Gyfosaht oder wie heisst das Zeug.',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 6, 55, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [48, 61]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'We have unique expertise in flood risk and are helping highlight ways that people can be better prepared the next time floodwaters rise. Our CEO Dermot Corry offers some perspective in this blog post. https://t.co/CgY1ezLcaY #hurricaneian',
#   'screen_name': 'millimaninsight',
#   'user_description': 'Independent actuarial firm with consulting practices in healthcare, employee benefits, property & casualty insurance, life insurance and financial services.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 21, 3, 30, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'hurricaneian', 'indices': [225, 238]}],
#   'urls': [{'url': 'https://t.co/CgY1ezLcaY',
#     'expanded_url': 'https://www.linkedin.com/pulse/reflecting-hurricane-ian-dermot-corry',
#     'display_url': 'linkedin.com/pulse/reflecti…',
#     'indices': [201, 224]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @gaillevyontv: Bayfront Bistro on Fort Myers Beach is back open! They’re serving cold drinks, hot food, and WIFI! Check out how high the…',
#   'screen_name': 'bogiegolferplus',
#   'user_description': 'Retired Teamster who enjoys Corvettes and Harleys..........proudly made in the USA with Norwegian parts.......follow bogiegolferplus on TruthSocial',
#   'favourite_count': 0,
#   'retweet_count': 7,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 59, 35, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'gaillevyontv',
#     'name': 'Gail Levy',
#     'id': 1004498563148275712,
#     'id_str': '1004498563148275712',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': "@KaifasSarah Yes mam, that's a tree that fell aside of my house after #HurricaneIan",
#   'screen_name': 'Donttre90985228',
#   'user_description': 'Gulf War 1990 -101stabn, ROK DMZ 88,94,00 Bosnia-97, Afghanistan-2004 U.S. Army Veteran, XLBullies, Constitutionalist\nGunshine state',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 55, 2, tzinfo=datetime.timezone.utc),
#   'replying_to': 'KaifasSarah',
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [70, 83]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'KaifasSarah',
#     'name': 'kafisss',
#     'id': 1483837279856701442,
#     'id_str': '1483837279856701442',
#     'indices': [0, 12]}],
#   'is_quote': False},
#  {'text': 'A visual of storm damage in Florida.\n\n#HurricaneSeason2022\n#HurricaneIan\n#HurricaneNicole\n\nhttps://t.co/BVueYGVv1a',
#   'screen_name': 'LittleFootLady',
#   'user_description': '#EnviroSci, adventure seeker, traveler, wannabe chef, veteran Marine, ... lover of growing things\n\n\n\n$DeviLittlefoot',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 31, 2, tzinfo=datetime.timezone.utc),
#   'replying_to': 'LittleFootLady',
#   'media': False,
#   'hashtags': [{'text': 'HurricaneSeason2022', 'indices': [38, 58]},
#    {'text': 'HurricaneIan', 'indices': [59, 72]},
#    {'text': 'HurricaneNicole', 'indices': [73, 89]}],
#   'urls': [{'url': 'https://t.co/BVueYGVv1a',
#     'expanded_url': 'https://www.tiktok.com/t/ZTRxvc9Kf/',
#     'display_url': 'tiktok.com/t/ZTRxvc9Kf/',
#     'indices': [91, 114]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': "Hello Everyone,\n1/10) Warning, the following #news report may feature scenes too intense for some viewers.\nHurricane Nicole Reiterates Florida's Home Insurance Hardship\nhttps://t.co/DOrgZHms1y\n#HurricaneNicole #HurricaneIan #TropicalStorm #Damage #HomeInsurance #Florida",
#   'screen_name': 'Find_and_Bind1',
#   'user_description': 'Amateur journalist, photographer, #bondage enthusiast and 100% professional. I am looking forward to handling new and exciting challenges.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 23, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'news', 'indices': [45, 50]},
#    {'text': 'HurricaneNicole', 'indices': [193, 209]},
#    {'text': 'HurricaneIan', 'indices': [210, 223]},
#    {'text': 'TropicalStorm', 'indices': [224, 238]},
#    {'text': 'Damage', 'indices': [239, 246]},
#    {'text': 'HomeInsurance', 'indices': [247, 261]},
#    {'text': 'Florida', 'indices': [262, 270]}],
#   'urls': [{'url': 'https://t.co/DOrgZHms1y',
#     'expanded_url': 'https://youtu.be/cjv_q7-qhOU',
#     'display_url': 'youtu.be/cjv_q7-qhOU',
#     'indices': [169, 192]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: A Fort Myers man filmed the catastrophic storm surge that trapped him inside his home as #HurricaneIan hit southwest F…',
#   'screen_name': 'ZaxBeez',
#   'user_description': '#Democrat #BlueCrew #ConnectBlue #BLM #ClimateChange #Resistance #FBR #ClimateChange #RenewableEnergy @1DrCole No 🚫DMs',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 22, 53, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [110, 123]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': '1st it was a boat-sinking parade;\nthen #HurricaneIan swamps the "sedition central" region of SW FL;\nthen Tiffany\'s wedding weekend gets ruined by #HurricaneNicole\n\nMaybe God\'s talking?\nBut some traitors (incl. fake "Christian leaders" who enable evil &amp; fraud) aren\'t listening?🤔 https://t.co/Aju3KEUYnE',
#   'screen_name': 'CitizenPatriot9',
#   'user_description': 'Love of God, Country & TRUTH.\nIntegrity,\nFidelity,\nCivic Duty,\n&Courage 2 stand up 4 Right.\nLove 4 Earth (& 4 all peoples).\nFight4Freedom: Arrest #TraitorTrump',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 22, 24, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [39, 52]},
#    {'text': 'HurricaneNicole', 'indices': [146, 162]}],
#   'urls': [{'url': 'https://t.co/Aju3KEUYnE',
#     'expanded_url': 'https://twitter.com/home414/status/1591519674252292101',
#     'display_url': 'twitter.com/home414/status…',
#     'indices': [283, 306]}],
#   'user_mentions': [],
#   'is_quote': True},
#  {'text': 'Ft. Myers Beach residents Tom &amp; Anne invited Red Cross volunteer Doreen to have a look inside their home, built in 1935, which was inundated by feet of water from #HurricaneIan storm surge. Clean-up supplies and compassion from the Red Cross will help w/ the exhausting job ahead. https://t.co/Za2murDbCj',
#   'screen_name': 'RedCrossCFL',
#   'user_description': 'Official site: American Red Cross of Central Florida & U.S. Virgin Islands. Serving our neighbors by mobilizing the power of volunteers & generosity of donors.',
#   'favourite_count': 13,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 10, 6, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [167, 180]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @GageGoulding: The 138-year-old Sanibel Lighthouse survived #HurricaneIan, but lost one of its legs. \n\nNow it has a temporary leg to hel…',
#   'screen_name': 'jewel_thin',
#   'user_description': '',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 9, 13, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [63, 76]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'GageGoulding',
#     'name': 'Gage Goulding - NBC2',
#     'id': 326890702,
#     'id_str': '326890702',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': '"Hello my friends, I\'m calling to you (...)"\n#Toto\n#Cuba #PinarDelRio #HurricaneIan #help #pianistgirl https://t.co/DZgtpppBO8',
#   'screen_name': 'anabelenr_music',
#   'user_description': '𝑀𝑢𝑠𝑖𝑐𝑖𝑎𝑛 🎹 • 15 𝑦𝑒𝑎𝑟𝑠 𝑜𝑙𝑑 😄 • 𝐶𝑢𝑏𝑎𝑛 🇨🇺 • 𝑁𝑎𝑡𝑢𝑟𝑒 𝑙𝑜𝑣𝑒𝑟 🌱 • TOTO/Luke fan ❤🎸🎶 • Dream: study a Music career in USA 🇺🇸',
#   'favourite_count': 2,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 20, 3, 20, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'Toto', 'indices': [45, 50]},
#    {'text': 'Cuba', 'indices': [51, 56]},
#    {'text': 'PinarDelRio', 'indices': [57, 69]},
#    {'text': 'HurricaneIan', 'indices': [70, 83]},
#    {'text': 'help', 'indices': [84, 89]},
#    {'text': 'pianistgirl', 'indices': [90, 102]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @Scientology: Hurricane Ian is Still a Disaster for Many Florida Families https://t.co/Jx6E3Umvh9 \n\n@ScientologyVM Volunteer Ministers c…',
#   'screen_name': 'JamiesonGarland',
#   'user_description': '✨',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 58, 54, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [{'url': 'https://t.co/Jx6E3Umvh9',
#     'expanded_url': 'https://bit.ly/3teToSi',
#     'display_url': 'bit.ly/3teToSi',
#     'indices': [77, 100]}],
#   'user_mentions': [{'screen_name': 'Scientology',
#     'name': 'Scientology',
#     'id': 22179835,
#     'id_str': '22179835',
#     'indices': [3, 15]},
#    {'screen_name': 'ScientologyVM',
#     'name': 'Volunteer Ministers',
#     'id': 105229085,
#     'id_str': '105229085',
#     'indices': [103, 117]}],
#   'is_quote': False},
#  {'text': 'A Fort Myers man filmed the catastrophic storm surge that trapped him inside his home as #HurricaneIan hit southwest Florida coastal towns.\n\nHis entire neighborhood, near the Caloosahatchee River in North Fort Myers, was flooded. \nhttps://t.co/DffJOHrld9 04',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 2,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 58, 26, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [89, 102]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @MyRadarWX: Horrific imagery coming out of Fort Myers Beach from MyRadar storm chaser @aaronjayjack after Major Hurricane Ian pushed sto…',
#   'screen_name': 'weather_russia',
#   'user_description': 'Meteorological observer of all countries of the world.  All natural phenomena and natural disasters are only here.',
#   'favourite_count': 0,
#   'retweet_count': 690,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 53, 8, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'MyRadarWX',
#     'name': 'MyRadar Weather',
#     'id': 702278455,
#     'id_str': '702278455',
#     'indices': [3, 13]},
#    {'screen_name': 'aaronjayjack',
#     'name': 'Aaron Jayjack',
#     'id': 9299392,
#     'id_str': '9299392',
#     'indices': [89, 102]}],
#   'is_quote': False},
#  {'text': 'RT @ToddBohannon: “After #HurricaneIan ripped thru Florida’s Gulf coast counties in late Sept, citrus growers in the state’s main agricultu…',
#   'screen_name': 'ToddBohannon',
#   'user_description': 'Educator/Nature-Worshiper/Activist: “We who believe in freedom cannot rest.” ~ Ella Baker',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 50, 11, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [25, 38]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'ToddBohannon',
#     'name': 'Todd (they/them) #AbolishThePolice',
#     'id': 527131496,
#     'id_str': '527131496',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': 'We are looking to help the West Coast grow back strong! 🌴💪 Feel free to contact us to bring the tropics back! ☀️🌴 \n•\n•\n•\n#westcoast #hurricaneian #landscape #landscaping #palmtree #palms #gls #generallandscapesolutions https://t.co/nBNZoRLtNN',
#   'screen_name': 'glsplants',
#   'user_description': 'A tree farm that grows palm and hedge plants with the option to install at low industry costs!! 🌴☀️',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 48, 8, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'westcoast', 'indices': [121, 131]},
#    {'text': 'hurricaneian', 'indices': [132, 145]},
#    {'text': 'landscape', 'indices': [146, 156]},
#    {'text': 'landscaping', 'indices': [157, 169]},
#    {'text': 'palmtree', 'indices': [170, 179]},
#    {'text': 'palms', 'indices': [180, 186]},
#    {'text': 'gls', 'indices': [187, 191]},
#    {'text': 'generallandscapesolutions', 'indices': [192, 218]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @disasterstrat: #Disabled disaster survivors, need help? Discapacitade, sobrevivió un desastre ¿necesita ayuda?\n\nCall (llame) o text Dis…',
#   'screen_name': 'melissamarsall',
#   'user_description': 'Director of Operations, Partnership for Inclusive Disability Strategies, disability rights activist, writer, JD,  supports disabled Ukranians, opinions mine',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 47, 42, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Disabled', 'indices': [19, 28]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'disasterstrat',
#     'name': 'The Partnership for Inclusive Disaster Strategies',
#     'id': 959440152522362885,
#     'id_str': '959440152522362885',
#     'indices': [3, 17]}],
#   'is_quote': False},
#  {'text': 'A Fort Myers man filmed the catastrophic storm surge that trapped him inside his home as #HurricaneIan hit southwest Florida coastal towns.\n\nHis entire neighborhood, near the Caloosahatchee River in North Fort Myers, was flooded. \nhttps://t.co/DffJOHrld9 02',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 2,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 39, 25, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [89, 102]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'Hurricane Ian is Still a Disaster for Many Florida Families https://t.co/Jx6E3Umvh9 \n\n@ScientologyVM Volunteer Ministers continue their disaster response in the aftermath of #HurricaneIan where recovery is far from over for many affected by the storm. https://t.co/V3A3B7hxpl',
#   'screen_name': 'Scientology',
#   'user_description': 'Watch @ScientologyTV on DIRECTV, https://t.co/uMa8Lqp4Qc, Roku, Apple TV, Fire TV and https://t.co/LhDOcBIdvb!',
#   'favourite_count': 10,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 25, 8, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [174, 187]}],
#   'urls': [{'url': 'https://t.co/Jx6E3Umvh9',
#     'expanded_url': 'https://bit.ly/3teToSi',
#     'display_url': 'bit.ly/3teToSi',
#     'indices': [60, 83]}],
#   'user_mentions': [{'screen_name': 'ScientologyVM',
#     'name': 'Volunteer Ministers',
#     'id': 105229085,
#     'id_str': '105229085',
#     'indices': [86, 100]}],
#   'is_quote': False},
#  {'text': "Mother nature can be a bitch at times that's for sure as Florida has found out #HurricaneIan #TropicalStormNicole",
#   'screen_name': 'GwolfyStorm91',
#   'user_description': 'Parody to life get used to it.\n🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f🏳️\u200d🌈🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f🇬🇧\nAre you ready?? supporter of democracy and human rights',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 16, 47, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [79, 92]},
#    {'text': 'TropicalStormNicole', 'indices': [93, 113]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @kodiak149: .@Vanguard_Group @BarclaysCIB @the_rutabega \nAre you an owner of @HeritagePCI \nTerrible customer service\nWaiting 7 weeks sin…',
#   'screen_name': 'SusanHu60863084',
#   'user_description': 'Believe in equality and justice for all. No DMs, no lists.',
#   'favourite_count': 0,
#   'retweet_count': 23,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 10, 54, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'kodiak149',
#     'name': 'kodiak149',
#     'id': 17444647,
#     'id_str': '17444647',
#     'indices': [3, 13]},
#    {'screen_name': 'Vanguard_Group',
#     'name': 'Vanguard',
#     'id': 61875147,
#     'id_str': '61875147',
#     'indices': [16, 31]},
#    {'screen_name': 'BarclaysCIB',
#     'name': 'Barclays Corporate & Investment Bank',
#     'id': 856524819948609536,
#     'id_str': '856524819948609536',
#     'indices': [32, 44]},
#    {'screen_name': 'the_rutabega',
#     'name': 'the rutabega',
#     'id': 900454999,
#     'id_str': '900454999',
#     'indices': [45, 58]},
#    {'screen_name': 'HeritagePCI',
#     'name': 'Heritage Insurance',
#     'id': 1136702616392675328,
#     'id_str': '1136702616392675328',
#     'indices': [80, 92]}],
#   'is_quote': False},
#  {'text': 'NFIP policies mainly cover unfinished drywall, insulation, mechanicals, plumbing and electrical. https://t.co/CKRFTOt6LA #hurricane #hurricaneian #florida #hurricaneseason #heretohelp #publicinsuranceadjuster #insurance #wemakeiteasier #flood #wind #help #helpisontheway #NFIP https://t.co/mJLqzGTOEn',
#   'screen_name': 'SwerlingWinnick',
#   'user_description': 'Swerling Milton Winnick navigates insurance issues, and advocates on your behalf to get you the best recovery possible.',
#   'favourite_count': 2,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 19, 0, 57, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'hurricane', 'indices': [121, 131]},
#    {'text': 'hurricaneian', 'indices': [132, 145]},
#    {'text': 'florida', 'indices': [146, 154]},
#    {'text': 'hurricaneseason', 'indices': [155, 171]},
#    {'text': 'heretohelp', 'indices': [172, 183]},
#    {'text': 'publicinsuranceadjuster', 'indices': [184, 208]},
#    {'text': 'insurance', 'indices': [209, 219]},
#    {'text': 'wemakeiteasier', 'indices': [220, 235]},
#    {'text': 'flood', 'indices': [236, 242]},
#    {'text': 'wind', 'indices': [243, 248]},
#    {'text': 'help', 'indices': [249, 254]},
#    {'text': 'helpisontheway', 'indices': [255, 270]},
#    {'text': 'NFIP', 'indices': [271, 276]}],
#   'urls': [{'url': 'https://t.co/CKRFTOt6LA',
#     'expanded_url': 'https://bit.ly/3NPih0n',
#     'display_url': 'bit.ly/3NPih0n',
#     'indices': [97, 120]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'A door that opens outward is no competition for the strong surge in Naples, FL from #HurricaneIan \nhttps://t.co/X5TpRu5R0E 04',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 18, 56, 23, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [84, 97]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: A door that opens outward is no competition for the strong surge in Naples, FL from #HurricaneIan \nhttps://t.co/X5TpRu…',
#   'screen_name': 'factbase4',
#   'user_description': "🌈 Doctor-BA #BidenHarris #BLM RIP #RBG Social, clim. jstc. & econ. ops for all. #meidasmighty #Hummingbird dad. Today I'm a lonely warrior! RT🚫Endorsement. 🌎",
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 18, 43, 41, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [105, 118]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'A door that opens outward is no competition for the strong surge in Naples, FL from #HurricaneIan \nhttps://t.co/X5TpRu5R0E 03',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 1,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 18, 43, 25, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [84, 97]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'Roof ripped off from #HurricaneIan at a motel in Punta Gorda, FL. Motel owner says one with minor injury. This video was taken in the calm of the eye.\nvia CharlesPeek \nhttps://t.co/AZ3ZuIno5w 03',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 2,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 12, 18, 29, 19, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [21, 34]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @TomthunkitsMind: A Fort Myers man filmed the catastrophic storm surge that trapped him inside his home as #HurricaneIan hit southwest F…',
#   'screen_name': 'ANTFACE1',
#   'user_description': '',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 18, 3, 54, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [110, 123]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'TomthunkitsMind',
#     'name': 'Tomthunkit™',
#     'id': 289118612,
#     'id_str': '289118612',
#     'indices': [3, 19]}],
#   'is_quote': False},
#  {'text': 'A Fort Myers man filmed the catastrophic storm surge that trapped him inside his home as #HurricaneIan hit southwest Florida coastal towns.\n\nHis entire neighborhood, near the Caloosahatchee River in North Fort Myers, was flooded. \nhttps://t.co/DffJOHrld9 01',
#   'screen_name': 'TomthunkitsMind',
#   'user_description': "Tomthunkit's Mind Diner is open 24/7. All-you-can-eat smorgasbord of hand-picked deliciously sweet tweets for your political palate. Invest ($) in your future",
#   'favourite_count': 3,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 12, 18, 2, 37, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [89, 102]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'Winter Park church volunteers take relief supplies to hurricane victims in southwest Florida. Action Church focuses on helping those in need, pastor says.\nhttps://t.co/c5xzkXhswz \n \n#volunteer #winterpark #orlando #hurricaneian #relief\nhttps://t.co/RmCoio7Spk https://t.co/thYz4zb9GW',
#   'screen_name': 'Park_ave_mag',
#   'user_description': '',
#   'favourite_count': 0,
# ...
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Cuba', 'indices': [115, 120]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'aldaboro714',
#     'name': 'aldaboro714',
#     'id': 1493669216825847810,
#     'id_str': '1493669216825847810',
#     'indices': [3, 15]},
#    {'screen_name': 'BrunoRguezP',
#     'name': 'Bruno Rodríguez P',
#     'id': 1074358534853271555,
#     'id_str': '1074358534853271555',
#     'indices': [40, 52]}],
#   'is_quote': False},
#  {'text': 'RT @BillMooreORL: #Hurricane #History repeating itself? Interesting graphic. #HurricaneCharley / #HurricaneJeanne versus #HurricaneIan / #H…',
#   'screen_name': 'Rev_Tone',
#   'user_description': '18+ Only AGE IN BIO OR ELSE \nNby Lesbian - She/They - 27 - White \nOccasionally NSFW \nheader by @splatbones \nicon @Kemafili1\n\n❤️@sashanein ❤️@sympolitedeluxe❤️',
#   'favourite_count': 0,
#   'retweet_count': 81,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 48, 36, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Hurricane', 'indices': [18, 28]},
#    {'text': 'History', 'indices': [29, 37]},
#    {'text': 'HurricaneCharley', 'indices': [77, 94]},
#    {'text': 'HurricaneJeanne', 'indices': [97, 113]},
#    {'text': 'HurricaneIan', 'indices': [121, 134]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'BillMooreORL',
#     'name': 'Bill Moore',
#     'id': 2936746690,
#     'id_str': '2936746690',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': 'RT @BillMooreORL: #Hurricane #History repeating itself? Interesting graphic. #HurricaneCharley / #HurricaneJeanne versus #HurricaneIan / #H…',
#   'screen_name': 'varshith1989',
#   'user_description': 'Why we are here on this planet 🌎',
#   'favourite_count': 0,
#   'retweet_count': 81,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 42, 26, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Hurricane', 'indices': [18, 28]},
#    {'text': 'History', 'indices': [29, 37]},
#    {'text': 'HurricaneCharley', 'indices': [77, 94]},
#    {'text': 'HurricaneJeanne', 'indices': [97, 113]},
#    {'text': 'HurricaneIan', 'indices': [121, 134]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'BillMooreORL',
#     'name': 'Bill Moore',
#     'id': 2936746690,
#     'id_str': '2936746690',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': 'RT @ZacSmithNEWS: $IVDN: World’s Most Energy Efficient House Wrap to Aid in the Rebuilding of Florida Homes After Hurricane Ian\nhttps://t.c…',
#   'screen_name': 'budfoxfun',
#   'user_description': '',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 41, 49, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'ZacSmithNEWS',
#     'name': 'Zac Smith',
#     'id': 977180786414833664,
#     'id_str': '977180786414833664',
#     'indices': [3, 16]}],
#   'is_quote': True},
#  {'text': 'RT @clairemetzwesh: Another home in #wilburbythesea. Only a bedroom &amp; garage left after it collapsed. The property first comprised in #Hurr…',
#   'screen_name': 'twxman911',
#   'user_description': 'Atlantic Hurricane coverage @twxman911 #AtlanticHurricanes #Atlantic #AtlanticOcean #GulfOfMexico #CaribbeanWx #Caribbean #Tropical #Tropics #flwx #swfl',
#   'favourite_count': 0,
#   'retweet_count': 33,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 40, 20, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'wilburbythesea', 'indices': [36, 51]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'clairemetzwesh',
#     'name': 'claire metz',
#     'id': 36577200,
#     'id_str': '36577200',
#     'indices': [3, 18]}],
#   'is_quote': False},
#  {'text': 'RT @StevePetyerak: Patio of Pirates Cove buckling in Daytona Beach Shores, FL where #Nicole is causing structures to collapse into the ocea…',
#   'screen_name': 'NEConforti',
#   'user_description': '| Systems Engineer | Technology Consultant | MSP Aficionado | Nerd | Car Guy | https://t.co/1tGpRMCDq2\n\nhttps://t.co/3Mzp5q6IkA',
#   'favourite_count': 0,
#   'retweet_count': 116,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 38, 50, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Nicole', 'indices': [84, 91]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'StevePetyerak',
#     'name': 'Steve Petyerak',
#     'id': 36205517,
#     'id_str': '36205517',
#     'indices': [3, 17]}],
#   'is_quote': False},
#  {'text': 'RT @StevePetyerak: Patio of Pirates Cove buckling in Daytona Beach Shores, FL where #Nicole is causing structures to collapse into the ocea…',
#   'screen_name': 'davidmiguel330',
#   'user_description': 'Sports journalist & Canes alum who has covered 2 NBA Finals, Play-by-Play Announcer of @sudamericana 4 @mediaprous - Subscribe- YouTube - David Miguel I',
#   'favourite_count': 0,
#   'retweet_count': 116,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 38, 23, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Nicole', 'indices': [84, 91]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'StevePetyerak',
#     'name': 'Steve Petyerak',
#     'id': 36205517,
#     'id_str': '36205517',
#     'indices': [3, 17]}],
#   'is_quote': False},
#  {'text': 'RT @UF_IFAS: The agricultural impact from #HurricaneIan is still being felt and assessed as #HurricaneNicole sweeps across the state. Overl…',
#   'screen_name': 'FloridaMosquito',
#   'user_description': 'Non-profit association consisting of professionals from #MosquitoControl, #PublicHealth, #Entomology, #Medicine & more! 💙💚💛🦟',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 38, 8, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [42, 55]},
#    {'text': 'HurricaneNicole', 'indices': [92, 108]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'UF_IFAS',
#     'name': 'UF IFAS Solutions',
#     'id': 361385033,
#     'id_str': '361385033',
#     'indices': [3, 11]}],
#   'is_quote': True},
#  {'text': '$IVDN: World’s Most Energy Efficient House Wrap to Aid in the Rebuilding of Florida Homes After Hurricane Ian\nhttps://t.co/Mg8eLc6Zor #HouseWrap #Insulation #HomeBuilding #HurricaneIan #FloridaStrong #FrontPageStocks #WallstreetBets https://t.co/dk68dLGILn',
#   'screen_name': 'ZacSmithNEWS',
#   'user_description': 'Everything I post here is for information purposes only.  I do not recommend that anyone buy or sell any stocks based on anything I post.',
#   'favourite_count': 2,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 38, 5, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HouseWrap', 'indices': [134, 144]},
#    {'text': 'Insulation', 'indices': [145, 156]},
#    {'text': 'HomeBuilding', 'indices': [157, 170]},
#    {'text': 'HurricaneIan', 'indices': [171, 184]},
#    {'text': 'FloridaStrong', 'indices': [185, 199]},
#    {'text': 'FrontPageStocks', 'indices': [200, 216]},
#    {'text': 'WallstreetBets', 'indices': [217, 232]}],
#   'urls': [{'url': 'https://t.co/Mg8eLc6Zor',
#     'expanded_url': 'https://www.einpresswire.com/article/596586899/world-s-most-energy-efficient-house-wrap-to-aid-in-the-rebuilding-of-florida-homes-after-hurricane-stock-symbol-ivdn',
#     'display_url': 'einpresswire.com/article/596586…',
#     'indices': [110, 133]},
#    {'url': 'https://t.co/dk68dLGILn',
#     'expanded_url': 'https://twitter.com/SwingTradeOTC/status/1590024940564189185',
#     'display_url': 'twitter.com/SwingTradeOTC/…',
#     'indices': [233, 256]}],
#   'user_mentions': [],
#   'is_quote': True},
#  {'text': "As #FEMA continues supporting the State of Florida and households affected by #HurricaneIan, field activities, such as Disaster Recovery Center (DRC) operations, are being curtailed for everyone's safety. Monitor local media for updates and follow directions from local officials. https://t.co/eQXoC81kjD",
#   'screen_name': 'TwittnRob',
#   'user_description': "🤔 What if? #BeReady 👉 https://t.co/wGJ9OmAHSg 😷 Know your risks ⚠️ https://t.co/FmCzYx7c03 👍 #Resilience 🇺🇸 Nat'l IMAT @FEMA ¡En Español!",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 35, 7, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'FEMA', 'indices': [3, 8]},
#    {'text': 'HurricaneIan', 'indices': [78, 91]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @StevePetyerak: Patio of Pirates Cove buckling in Daytona Beach Shores, FL where #Nicole is causing structures to collapse into the ocea…',
#   'screen_name': 'mary0611bb',
#   'user_description': 'Definitely NOT a Trumper but I am a Republican who loves everyone no matter their political party. Humans don’t deserve animals',
#   'favourite_count': 0,
#   'retweet_count': 116,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 34, 43, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Nicole', 'indices': [84, 91]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'StevePetyerak',
#     'name': 'Steve Petyerak',
#     'id': 36205517,
#     'id_str': '36205517',
#     'indices': [3, 17]}],
#   'is_quote': False},
#  {'text': 'RT @BillMooreORL: #Hurricane #History repeating itself? Interesting graphic. #HurricaneCharley / #HurricaneJeanne versus #HurricaneIan / #H…',
#   'screen_name': 'SE_CaffreySmith',
#   'user_description': 'fiction writer, Bardian, reader, believer, admirer of natural beauty and art, open doors and the promise of the human spirit',
#   'favourite_count': 0,
#   'retweet_count': 81,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 31, 50, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Hurricane', 'indices': [18, 28]},
#    {'text': 'History', 'indices': [29, 37]},
#    {'text': 'HurricaneCharley', 'indices': [77, 94]},
#    {'text': 'HurricaneJeanne', 'indices': [97, 113]},
#    {'text': 'HurricaneIan', 'indices': [121, 134]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'BillMooreORL',
#     'name': 'Bill Moore',
#     'id': 2936746690,
#     'id_str': '2936746690',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': "#ThankfulThursday 🍁 🍂\nWell, AmeriLife of Sara-Bay is certainly thankful our office didn't blow away! 😂 #HurricaneIan #HurricaneNicole\nDon't forget to be #THANKFUL this holiday season!\n#AmeriLife #Thanksgiving #November2022 #CountYourBlessings https://t.co/rsIevH0S9H",
#   'screen_name': 'AmeriLifeofSB',
#   'user_description': 'Providing Life, Health, and Annuity Solutions for 50+ Years\n5540 E State Rd 64, Suite 200, Bradenton, FL 34208\n941-753-5688\n#AmeriLife #HIRING #Insurance',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 25, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'ThankfulThursday', 'indices': [0, 17]},
#    {'text': 'HurricaneIan', 'indices': [103, 116]},
#    {'text': 'HurricaneNicole', 'indices': [117, 133]},
#    {'text': 'THANKFUL', 'indices': [153, 162]},
#    {'text': 'AmeriLife', 'indices': [184, 194]},
#    {'text': 'Thanksgiving', 'indices': [195, 208]},
#    {'text': 'November2022', 'indices': [209, 222]},
#    {'text': 'CountYourBlessings', 'indices': [223, 242]}],
#   'urls': [],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'MOMENTS AGO: FPL: “All of our customers who were impacted by  #HurricaneIan who are able to accept power … have been restored.” #HurricaneNicole https://t.co/3H6XOEWx3i https://t.co/SNpXBwX4lD',
#   'screen_name': 'CBS12',
#   'user_description': 'Covering Palm Beach, Martin, St. Lucie, Indian River & Okeechobee • Got a newstip? Email us: newstips@cbs12.com • 561-881-0796',
#   'favourite_count': 3,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 24, 43, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': True,
#   'hashtags': [{'text': 'HurricaneIan', 'indices': [62, 75]},
#    {'text': 'HurricaneNicole', 'indices': [128, 144]}],
#   'urls': [{'url': 'https://t.co/3H6XOEWx3i',
#     'expanded_url': 'https://bit.ly/3Glkv6j',
#     'display_url': 'bit.ly/3Glkv6j',
#     'indices': [145, 168]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @BillMooreORL: #Hurricane #History repeating itself? Interesting graphic. #HurricaneCharley / #HurricaneJeanne versus #HurricaneIan / #H…',
#   'screen_name': 'MizHernandez01',
#   'user_description': 'Es facil hallar amigos, muy difícil conservar, es la escuela de la vida, la que me a enseñado más, ha habido muchos tropiezos.#esneta #larryhernandez🐾bb Raskal',
#   'favourite_count': 0,
#   'retweet_count': 81,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 21, 4, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Hurricane', 'indices': [18, 28]},
#    {'text': 'History', 'indices': [29, 37]},
#    {'text': 'HurricaneCharley', 'indices': [77, 94]},
#    {'text': 'HurricaneJeanne', 'indices': [97, 113]},
#    {'text': 'HurricaneIan', 'indices': [121, 134]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'BillMooreORL',
#     'name': 'Bill Moore',
#     'id': 2936746690,
#     'id_str': '2936746690',
#     'indices': [3, 16]}],
#   'is_quote': False},
#  {'text': 'RT @WxAndMovies: That’s actually scary how basically identical the tracks are. I guess history can repeat itself. #HurricanNicole #Hurrican…',
#   'screen_name': 'GibbyDierickx',
#   'user_description': 'Amateur meteorologist | High school golfer | 17 years old | Christian ✝ | hurricane count 9 | graduation 2024 |',
#   'favourite_count': 0,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 20, 37, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'HurricanNicole', 'indices': [114, 129]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'WxAndMovies',
#     'name': 'Everything Weather & Movies',
#     'id': 1146495374858883076,
#     'id_str': '1146495374858883076',
#     'indices': [3, 15]}],
#   'is_quote': True},
#  {'text': 'Hello Everyone,\n1/20) Late breaking #news....\nWarning, please be careful of down power lines. They can be dangerous.\nTropical Storm Nicole lashes Florida\nhttps://t.co/DHnQbmTvAI\n#HurricaneIan #Damage #TropicalStormNicole #Florida',
#   'screen_name': 'Find_and_Bind1',
#   'user_description': 'Amateur journalist, photographer, #bondage enthusiast and 100% professional. I am looking forward to handling new and exciting challenges.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 19, 44, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'news', 'indices': [36, 41]},
#    {'text': 'HurricaneIan', 'indices': [178, 191]},
#    {'text': 'Damage', 'indices': [192, 199]},
#    {'text': 'TropicalStormNicole', 'indices': [200, 220]},
#    {'text': 'Florida', 'indices': [221, 229]}],
#   'urls': [{'url': 'https://t.co/DHnQbmTvAI',
#     'expanded_url': 'https://youtu.be/rlpslmv1z3c',
#     'display_url': 'youtu.be/rlpslmv1z3c',
#     'indices': [154, 177]}],
#   'user_mentions': [],
#   'is_quote': False},
#  {'text': 'RT @StevePetyerak: Patio of Pirates Cove buckling in Daytona Beach Shores, FL where #Nicole is causing structures to collapse into the ocea…',
#   'screen_name': 'spike3401',
#   'user_description': '31 years old, proud father, proudly taken, amazon full-time married 10.07.2017',
#   'favourite_count': 0,
#   'retweet_count': 116,
#   'created_at': datetime.datetime(2022, 11, 10, 19, 18, 47, tzinfo=datetime.timezone.utc),
#   'replying_to': None,
#   'media': False,
#   'hashtags': [{'text': 'Nicole', 'indices': [84, 91]}],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'StevePetyerak',
#     'name': 'Steve Petyerak',
#     'id': 36205517,
#     'id_str': '36205517',
#     'indices': [3, 17]}],
#   'is_quote': False}]

# %% [markdown]
# I'll be storing all these raw files in csv.gz format since there's a lot to be sorted through.

# %%
import pandas as pd

df = pd.DataFrame(output)
df.to_csv('output_Oct_12_pm.csv.gz', mode='a', header=False, compression= 'gzip')

# %% [markdown]
# Taking a look at the shape of the csv I just saved.

# %%
df.shape
# Out:
# (628, 12)

# %% [markdown]
# Taking a look at the most recent 10 tweet rows in the df

# %%
df.tail(10)
# Out:
#                                                   text      screen_name  \
# 618  $IVDN: World’s Most Energy Efficient House Wra...     ZacSmithNEWS
# 619  As #FEMA continues supporting the State of Flo...        TwittnRob
# 620  RT @StevePetyerak: Patio of Pirates Cove buckl...       mary0611bb
# 621  RT @BillMooreORL: #Hurricane #History repeatin...  SE_CaffreySmith
# 622  #ThankfulThursday 🍁 🍂\nWell, AmeriLife of Sara...    AmeriLifeofSB
# 623  MOMENTS AGO: FPL: “All of our customers who we...            CBS12
# 624  RT @BillMooreORL: #Hurricane #History repeatin...   MizHernandez01
# 625  RT @WxAndMovies: That’s actually scary how bas...    GibbyDierickx
# 626  Hello Everyone,\n1/20) Late breaking #news.......   Find_and_Bind1
# 627  RT @StevePetyerak: Patio of Pirates Cove buckl...        spike3401
#
#                                       user_description  favourite_count  \
# 618  Everything I post here is for information purp...                2
# 619  🤔 What if? #BeReady 👉 https://t.co/wGJ9OmAHSg ...                0
# 620  Definitely NOT a Trumper but I am a Republican...                0
# 621  fiction writer, Bardian, reader, believer, adm...                0
# 622  Providing Life, Health, and Annuity Solutions ...                1
# 623  Covering Palm Beach, Martin, St. Lucie, Indian...                3
# 624  Es facil hallar amigos, muy difícil conservar,...                0
# 625  Amateur meteorologist | High school golfer | 1...                0
# 626  Amateur journalist, photographer, #bondage ent...                0
# 627  31 years old, proud father, proudly taken, ama...                0
#
#      retweet_count                created_at replying_to  media  \
# 618              1 2022-11-10 19:38:05+00:00        None  False
# 619              0 2022-11-10 19:35:07+00:00        None   True
# 620            116 2022-11-10 19:34:43+00:00        None  False
# 621             81 2022-11-10 19:31:50+00:00        None  False
# 622              0 2022-11-10 19:25:00+00:00        None   True
# 623              0 2022-11-10 19:24:43+00:00        None   True
# 624             81 2022-11-10 19:21:04+00:00        None  False
# 625              2 2022-11-10 19:20:37+00:00        None  False
# 626              0 2022-11-10 19:19:44+00:00        None  False
# 627            116 2022-11-10 19:18:47+00:00        None  False
#
#                                               hashtags  \
# 618  [{'text': 'HouseWrap', 'indices': [134, 144]},...
# 619  [{'text': 'FEMA', 'indices': [3, 8]}, {'text':...
# 620          [{'text': 'Nicole', 'indices': [84, 91]}]
# 621  [{'text': 'Hurricane', 'indices': [18, 28]}, {...
# 622  [{'text': 'ThankfulThursday', 'indices': [0, 1...
# 623  [{'text': 'HurricaneIan', 'indices': [62, 75]}...
# 624  [{'text': 'Hurricane', 'indices': [18, 28]}, {...
# 625  [{'text': 'HurricanNicole', 'indices': [114, 1...
# 626  [{'text': 'news', 'indices': [36, 41]}, {'text...
# 627          [{'text': 'Nicole', 'indices': [84, 91]}]
#
#                                                   urls  \
# 618  [{'url': 'https://t.co/Mg8eLc6Zor', 'expanded_...
# 619                                                 []
# 620                                                 []
# 621                                                 []
# 622                                                 []
# 623  [{'url': 'https://t.co/3H6XOEWx3i', 'expanded_...
# 624                                                 []
# 625                                                 []
# 626  [{'url': 'https://t.co/DHnQbmTvAI', 'expanded_...
# 627                                                 []
#
#                                          user_mentions  is_quote
# 618                                                 []      True
# 619                                                 []     False
# 620  [{'screen_name': 'StevePetyerak', 'name': 'Ste...     False
# 621  [{'screen_name': 'BillMooreORL', 'name': 'Bill...     False
# 622                                                 []     False
# 623                                                 []     False
# 624  [{'screen_name': 'BillMooreORL', 'name': 'Bill...     False
# 625  [{'screen_name': 'WxAndMovies', 'name': 'Every...      True
# 626                                                 []     False
# 627  [{'screen_name': 'StevePetyerak', 'name': 'Ste...     False
